# %% [markdown]
# <a href="https://colab.research.google.com/github/robledoirismar230-stack/Proyecto-Dashboard-Completo/blob/main/Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

# Datos
productos = ["Manzanas", "Uvas", "Peras", "Bananos"]
ventas = [70, 58, 63, 90]

fig, ax = plt.subplots(2, 3, figsize=(15, 8))

ax_flat = ax.flatten()

configuraciones = [
    {'tipo': 'bar', 'color': 'skyblue', 'titulo': 'Vertical (Cielo)'},
    {'tipo': 'barh', 'color': 'lightcoral', 'titulo': 'Horizontal (Coral)'},
    {'tipo': 'bar', 'color': 'lightgreen', 'titulo': 'Vertical (Verde)'},
    {'tipo': 'barh', 'color': 'gold', 'titulo': 'Horizontal (Oro)'},
    {'tipo': 'bar', 'color': 'grey', 'titulo': 'Vertical (Gris)'},
    {'tipo': 'barh', 'color': 'plum', 'titulo': 'Horizontal (Ciruela)'},
]

for i, axi in enumerate(ax_flat):
    config = configuraciones[i]

    if config['tipo'] == 'bar':
        axi.bar(productos, ventas, color=config['color'])
        axi.set_ylabel("Ventas")
        axi.set_xlabel("Productos")
        axi.grid(axis='y', alpha=0.5)
    else: # Gráfico de barras horizontal
        axi.barh(productos, ventas, color=config['color'])
        axi.set_xlabel("Ventas")
        axi.set_ylabel("Productos")
        axi.grid(axis='x', alpha=0.5)

    axi.set_title(config['titulo'], fontsize=12)

plt.suptitle("Distribución de Ventas por Producto en Subplots 2x3", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

# Datos
productos = ["sueters", "pantalones", "zapatos", "camisas"]
ventas = [198, 231, 140, 155]

fig, ax = plt.subplots(2, 3, figsize=(15, 8))

ax_flat = ax.flatten()

configuraciones = [
    {'tipo': 'bar', 'color': 'skyblue', 'titulo': 'Vertical (Cielo)'},
    {'tipo': 'barh', 'color': 'lightcoral', 'titulo': 'Horizontal (Coral)'},
    {'tipo': 'bar', 'color': 'lightgreen', 'titulo': 'Vertical (Verde)'},
    {'tipo': 'barh', 'color': 'gold', 'titulo': 'Horizontal (Oro)'},
    {'tipo': 'bar', 'color': 'grey', 'titulo': 'Vertical (Gris)'},
    {'tipo': 'barh', 'color': 'plum', 'titulo': 'Horizontal (Ciruela)'},
]

for i, axi in enumerate(ax_flat):
    config = configuraciones[i]

    if config['tipo'] == 'bar':
        axi.bar(productos, ventas, color=config['color'])
        axi.set_ylabel("Ventas")
        axi.set_xlabel("Productos")
        axi.grid(axis='y', alpha=0.5)
    else: # Gráfico de barras horizontal
        axi.barh(productos, ventas, color=config['color'])
        axi.set_xlabel("Ventas")
        axi.set_ylabel("Productos")
        axi.grid(axis='x', alpha=0.5)

    axi.set_title(config['titulo'], fontsize=12)

plt.suptitle("Distribución de Ventas de frutas", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

temperaturas = np.random.normal(28, 2, 40)

fig, ax = plt.subplots(2, 3, figsize=(15, 8))

ax_flat = ax.flatten()

bins_list = [5, 8, 10, 15, 20, 25]

for i, axi in enumerate(ax_flat):
    n_bins = bins_list[i]

    axi.hist(temperaturas,
             bins=n_bins,
             color='lightgreen',
             edgecolor='black',
             alpha=0.8)

    axi.set_title(f"Histograma con {n_bins} Bins", fontsize=12)
    axi.set_xlabel("Temperatura (°C)")
    axi.set_ylabel("Frecuencia")
    axi.grid(axis='y', alpha=0.3)

    axi.set_xlim(min(temperaturas) - 1, max(temperaturas) + 1)

plt.suptitle("Distribucion de temperaturas en Panamá", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

temperaturas = np.random.normal(25, 2, 40)

fig, ax = plt.subplots(2, 3, figsize=(15, 8))

ax_flat = ax.flatten()

bins_list = [5, 8, 10, 15, 20, 25]

for i, axi in enumerate(ax_flat):
    n_bins = bins_list[i]

    axi.hist(temperaturas,
             bins=n_bins,
             color='lightgreen',
             edgecolor='black',
             alpha=0.8)

    axi.set_title(f"Histograma con {n_bins} Bins", fontsize=12)
    axi.set_xlabel("Temperatura (°C)")
    axi.set_ylabel("Frecuencia")
    axi.grid(axis='y', alpha=0.3)

    axi.set_xlim(min(temperaturas) - 1, max(temperaturas) + 1)

plt.suptitle("Distribución de Temperaturas en Colombia", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos
alturas = [1.50, 1.55, 1.60, 1.65, 1.70, 1.75, 1.80]
pesos = [50, 55, 65, 60, 70, 75, 80]
colores = ['blue', 'red', 'green', 'purple', 'orange', 'black']
tamanos = [50, 100, 150, 200, 250, 300]

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15, 8))

ax_flat = ax.flatten()

for i, axi in enumerate(ax_flat):

    axi.scatter(alturas, pesos,
                color=colores[i],
                s=tamanos[i],
                alpha=0.7)

    axi.set_title(f"Gráfico {i+1} ({colores[i].capitalize()})", fontsize=12)
    axi.set_xlabel("Altura (h)")
    axi.set_ylabel("Peso (kg)")
    axi.grid(True, alpha=0.3)

plt.suptitle("Visualización de Altura vs. Peso en Subplots 2x3", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos
categorias = ["Panama", "Veraguas", "Cocle", "Bocas del toro"]
valores = [30, 15, 3, 1]
# Para que una rebanada (Panamá) se separe del resto en algunos subplots
explotar = (0.1, 0, 0, 0)
# Definición de colores
colores = ['#4CAF50', '#FF9800', '#2196F3', '#9C27B0'] # Colores con un estilo de dashboard

# 1. Crear la figura y los 6 ejes (3 filas, 2 columnas)
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(12, 12))

# 2. Aplanar el array de ejes para iterar fácilmente
ax_flat = ax.flatten()

# 3. Definir las configuraciones para cada uno de los 6 subplots (el "dashboard")
configuraciones = [
    # Fila 1
    {'titulo': 'Gráfico 1: Porcentaje con Sombra', 'explode': None, 'shadow': True},
    {'titulo': 'Gráfico 2: Separación (Panamá)', 'explode': explotar, 'shadow': False},
    # Fila 2
    {'titulo': 'Gráfico 3: Inicio en 90°', 'startangle': 90, 'explode': None, 'shadow': False},
    {'titulo': 'Gráfico 4: Sin Etiquetas', 'labels': None, 'explode': None, 'shadow': False},
    # Fila 3
    {'titulo': 'Gráfico 5: Texto Blanco', 'autopct_color': 'white', 'explode': None, 'shadow': False},
    {'titulo': 'Gráfico 6: Borde Rojo', 'wedgeprops': {'linewidth': 1, 'edgecolor': 'red'}, 'explode': None, 'shadow': False}
]

# 4. Iterar sobre cada eje (subplot) para dibujar el gráfico
for i, axi in enumerate(ax_flat):
    config = configuraciones[i]

    # Parámetros básicos
    params = {
        'x': valores,
        'labels': categorias,
        'autopct': '%1.1f%%',
        'colors': colores,
        'explode': config.get('explode'),
        'shadow': config.get('shadow', False),
        'startangle': config.get('startangle', 0),
        'wedgeprops': config.get('wedgeprops', {}),
        'textprops': {'color': config.get('autopct_color', 'black')}
    }

    # Dibujar el gráfico de pastel en el eje actual (axi)
    axi.pie(**params)

    # Configurar título del subplot
    axi.set_title(config['titulo'], fontsize=11)

# 5. Título principal y ajuste de diseño
plt.suptitle("Dashboard de Provincias Visitadas", fontsize=18, y=1.02)
plt.tight_layout()
plt.show()
